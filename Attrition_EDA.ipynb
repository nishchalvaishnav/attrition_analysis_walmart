# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Attrition.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
plt.figure(figsize =(10, 4))
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap ='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ### as we can see there are no missing values with help of Heatmap

# %%
# import sys
# !{sys.executable} -m pip install pandas-profiling

# %%
# import pandas_profiling as pp

# %%
# profile = pp.ProfileReport(df)
# profile.to_file("Attrition.csv")

# %%
# !pip install -q pandasai

# %%
# from pandasai import PandasAI
# from pandasai.llm.openai import OpenAI

# %%
# llm = OpenAI(api_token="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")
# pandas_ai = PandasAI(llm, conversational=False)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df["Department"]
# Out:
# 0                        Sales
# 1       Research & Development
# 2       Research & Development
# 3       Research & Development
# 4       Research & Development
#                  ...
# 1465    Research & Development
# 1466    Research & Development
# 1467    Research & Development
# 1468                     Sales
# 1469    Research & Development
# Name: Department, Length: 1470, dtype: object

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.isnull().count()
# Out:
# Age                         1470
# Attrition                   1470
# BusinessTravel              1470
# DailyRate                   1470
# Department                  1470
# DistanceFromHome            1470
# Education                   1470
# EducationField              1470
# EmployeeCount               1470
# EmployeeNumber              1470
# EnvironmentSatisfaction     1470
# Gender                      1470
# HourlyRate                  1470
# JobInvolvement              1470
# JobLevel                    1470
# JobRole                     1470
# JobSatisfaction             1470
# MaritalStatus               1470
# MonthlyIncome               1470
# MonthlyRate                 1470
# NumCompaniesWorked          1470
# Over18                      1470
# OverTime                    1470
# PercentSalaryHike           1470
# PerformanceRating           1470
# RelationshipSatisfaction    1470
# StandardHours               1470
# StockOptionLevel            1470
# ...

# %%
# What is the ATTRITION RATE of company?
attrition_count = df["Attrition"].value_counts()

# %%
count_yes = attrition_count["Yes"]
count_no = attrition_count["No"]
total_employee = count_yes + count_no

attrition_rate = (count_yes/total_employee)*100

# %%
print(f"Attrition rate = {attrition_rate:.2f}%")
# Out:
# Attrition rate = 16.12%

# %%
plt.pie(attrition_count)
# Out:
# ([<matplotlib.patches.Wedge at 0x257b54bb610>,
# ...
#  [Text(-0.9618916732177651, 0.5336332157899547, ''),
#   Text(0.961891673217765, -0.5336332157899547, '')])

# %%
age_group = df.groupby('Age')['Attrition'].value_counts(normalize=True).unstack().fillna(0)

# %%
attrition_rates = age_group['Yes'] * 100

# %%
print(attrition_rates)
# Out:
# Age
# 18    50.000000
# 19    66.666667
# 20    54.545455
# 21    46.153846
# 22    31.250000
# 23    28.571429
# 24    26.923077
# 25    23.076923
# 26    30.769231
# 27     6.250000
# 28    29.166667
# 29    26.470588
# 30    15.000000
# 31    26.086957
# 32    18.032787
# 33    20.689655
# 34    11.688312
# 35    12.820513
# 36     8.695652
# 37    12.000000
# 38     3.448276
# 39    14.285714
# 40     8.771930
# 41    15.000000
# 42     4.347826
# 43     6.250000
# 44    18.181818
# 45     4.878049
# 46    12.121212
# 47    12.500000
# 48    10.526316
# 49     8.333333
# 50    16.666667
# 51    10.526316
# 52    16.666667
# 53    10.526316
# 54     0.000000
# 55    13.636364
# 56    21.428571
# 57     0.000000
# 58    35.714286
# 59     0.000000
# 60     0.000000
# Name: Yes, dtype: float64

# %%
attrition_rates.plot.bar()
# Out:
# <Axes: xlabel='Age'>

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df["EnvironmentSatisfaction"].value_counts()
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
satisfaction_groups = df.groupby('EnvironmentSatisfaction')['Attrition'].value_counts(normalize=True).unstack().fillna(0)
attrition_rates = satisfaction_groups['Yes'] * 100

print(attrition_rates)
# Out:
# EnvironmentSatisfaction
# 1    25.352113
# 2    14.982578
# 3    13.686534
# 4    13.452915
# Name: Yes, dtype: float64

# %% [markdown]
# # so here we can see greater the satisfaction lower the Attrition rate.

# %%
attrition_rates_df = attrition_rates.reset_index()
attrition_rates_df.columns = ['Satisfaction', 'AttritionRate']

print(attrition_rates_df)
# Out:
#    Satisfaction  AttritionRate
# 0             1      25.352113
# 1             2      14.982578
# 2             3      13.686534
# 3             4      13.452915

# %%
plt.figure(figsize=(10, 6))
plt.bar(attrition_rates_df['Satisfaction'], attrition_rates_df['AttritionRate'], color='blue')
plt.title('Job Satisfaction vs. Attrition Rate')
plt.xlabel('Job Satisfaction')
plt.ylabel('Attrition Rate')
plt.grid(True)
plt.show()

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.head(50)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df["Department"].nunique()
# Out:
# 3

# %%
df["Department"].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df["Education"].unique()
# Out:
# array([2, 1, 4, 3, 5], dtype=int64)

# %%
eduction_level_high = df.loc[df["Education"] >3, "Gender"]

# %%
df.groupby(eduction_level_high).mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7256\1919832873.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(eduction_level_high).mean()
#               Age   DailyRate  DistanceFromHome  Education  EmployeeCount  \
# Gender
# Female  39.414773  793.414773          9.778409   4.125000            1.0
# Male    39.303704  819.188889          8.974074   4.096296            1.0
#
#         EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Gender
# Female      997.261364                 2.625000   65.931818        2.732955
# Male       1085.492593                 2.659259   66.581481        2.748148
#
#         JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# Gender            ...
# Female  2.232955  ...                  2.693182           80.0
# ...

# %% [markdown]
# ### we have created new dataframe from existing dataframe

# %%
new_df = df[['Education',"Gender"]].copy()
new_df
# Out:
#       Education  Gender
# 0             2  Female
# 1             1    Male
# 2             2    Male
# 3             4  Female
# 4             1    Male
# ...         ...     ...
# 1465          2    Male
# 1466          1    Male
# 1467          3    Male
# 1468          3    Male
# 1469          3    Male
#
# [1470 rows x 2 columns]

# %% [markdown]
# ### here we have counted number of employees based on education lavel by GENDER

# %%
new_df.groupby("Education").value_counts()
# Out:
# Education  Gender
# 1          Male      110
#            Female     60
# 2          Male      165
#            Female    117
# 3          Male      337
#            Female    235
# 4          Male      244
#            Female    154
# 5          Male       26
#            Female     22
# dtype: int64

# %%
new_df.groupby("Education").value_counts().plot.bar()
# Out:
# <Axes: xlabel='Education,Gender'>

# %%
df["JobLevel"].nunique()
# Out:
# 5

# %%
df.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
# new_df_jobLevel = df.groupby(["Yes=1 and No=0","Gender"])["JobLevel"].value_counts()

# %%
new_df_jobLevel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 new_df_jobLevel
#
# NameError: name 'new_df_jobLevel' is not defined

# %%
new_df_jobLevel.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 new_df_jobLevel.plot.bar()
#
# NameError: name 'new_df_jobLevel' is not defined

# %% [markdown]
# ## Upper side we can see Higher the job level, lower the attrition rate

# %%
attrition_count = df["Attrition"].value_counts()

# %%
plt.pie(attrition_count,labels=["No","Yes"],explode=(0.2,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x257b63d6ce0>,
# ...
#  [Text(-1.136781068348268, 0.6306574368426737, 'No'),
#   Text(0.961891673217765, -0.5336332157899547, 'Yes')])

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### droping two columns as they have no specefic value in dataset

# %%
df = df.drop(["EmployeeCount","EmployeeNumber"],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
attrition_col = pd.get_dummies(df["Attrition"])
attrition_col.head()
# Out:
#    No  Yes
# 0   0    1
# 1   1    0
# 2   0    1
# 3   1    0
# 4   1    0

# %%
df = pd.concat([df,attrition_col],axis=1)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
df = df.drop(["Attrition","No"],axis=1)
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  ...  StandardHours  StockOptionLevel TotalWorkingYears  \
# 0  Female          94  ...             80                 0                 8
# ...

# %%
df = df.rename(columns = {"Yes":"Yes=1 and No=0"})
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  HourlyRate  ...  StandardHours  StockOptionLevel TotalWorkingYears  \
# 0  Female          94  ...             80                 0                 8
# ...

# %%
import seaborn as sns

# %% [markdown]
# ## so we can see male ratio is greater then females who are

# %%
sns.barplot(x="Gender",y="Yes=1 and No=0", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Yes=1 and No=0'>

# %%
df.groupby("Gender").nunique()
# Out:
#         Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# Gender
# Female   42               3        477           3                29
# Male     43               3        635           3                29
#
#         Education  EducationField  EnvironmentSatisfaction  HourlyRate  \
# Gender
# Female          5               6                        4          71
# Male            5               6                        4          71
#
#         JobInvolvement  ...  StandardHours  StockOptionLevel  \
# Gender                  ...
# Female               4  ...              1                 4
# Male                 4  ...              1                 4
#
#         TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# Gender
# Female                 39                      7                4
# Male                   40                      7                4
#
#         YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# Gender
# ...

# %%
female_yes_count = df[(df["Gender"]=="Female") & (df["Yes=1 and No=0"]==1)].shape[0]
print("female_yes_count",female_yes_count)
female_no_count = df[(df["Gender"]=="Female") & (df["Yes=1 and No=0"]==0)].shape[0]
print("female_no_count",female_no_count)
male_yes_count = df[(df["Gender"]=="Male") & (df["Yes=1 and No=0"]==1)].shape[0]
print("male_yes_count",male_yes_count)
male_no_count = df[(df["Gender"]=="Male") & (df["Yes=1 and No=0"]==0)].shape[0]
print("male_no_count",male_no_count)
# Out:
# female_yes_count 87
# female_no_count 501
# male_yes_count 150
# male_no_count 732

# %%
total_female_count = df[df["Gender"]=="Female"].shape[0]
print("total_female_count_in_company",total_female_count)
total_male_count = df[df["Gender"]=="Male"].shape[0]
print("total_male_count_in_company", total_male_count)
# Out:
# total_female_count_in_company 588
# total_male_count_in_company 882

# %%
plt.figure(figsize=(8,6))
plt.bar(["Female","Male"],[total_female_count,total_male_count],color=["pink","blue"])
plt.title("Total count of Male and Female Employees")
plt.xlabel("Gender")
plt.ylabel("Total count")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.bar(["Yes","No"],[female_yes_count,female_no_count],color=["blue","red"])
plt.title("Female Employees Attrition 'Yes' vs 'No'")
plt.xlabel("Attrition")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.bar(["Yes","No"],[male_yes_count,male_no_count],color=["blue","red"])
plt.title("male Employees Attrition 'Yes' vs 'No'")
plt.xlabel("Attrition")
plt.ylabel("Count")
plt.show()

# %%
female_yes_ratio = female_yes_count/total_female_count
print(f"female yes ratio: {female_yes_ratio:.2f}")

female_no_ratio = female_no_count/total_female_count
print(f"female NO ratio: {female_no_ratio:.2f}")
# Out:
# female yes ratio: 0.15
# female NO ratio: 0.85

# %%
sns.barplot(x="BusinessTravel",y="Yes=1 and No=0", data=df)
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='Yes=1 and No=0'>

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr())
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7256\2097957921.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1470 non-null   object
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobLevel                  1470 non-null   int64
#  12  JobRole                   1470 non-null   object
#  13  JobSatisfaction           1470 non-null   int64
# ...

# %%
sns.distplot(df.DistanceFromHome)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7256\3317853923.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.DistanceFromHome)

# %%
sns.distplot(df.MonthlyIncome)
plt.show()

df["MonthlyIncome_sqrt"] = np.sqrt(df.MonthlyIncome)
sns.distplot(df.MonthlyIncome_sqrt)
plt.show()

df["MonthlyIncome_log"] = np.log(df.MonthlyIncome)
sns.distplot(df.MonthlyIncome_log)
plt.show()

df["MonthlyIncome_cbrt"] = np.cbrt(df.MonthlyIncome)
sns.distplot(df.MonthlyIncome_cbrt)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7256\3704032135.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.MonthlyIncome)
# C:\Users\HP\AppData\Local\Temp\ipykernel_7256\3704032135.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.MonthlyIncome_sqrt)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1470 non-null   object
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobLevel                  1470 non-null   int64
#  12  JobRole                   1470 non-null   object
#  13  JobSatisfaction           1470 non-null   int64
# ...

# %% [markdown]
# ## how monthly income, stock option level, and percent salary hike relate to attrition.

# %%
plt.figure(figsize=(12, 4))

sns.histplot(df["MonthlyIncome"], bins=30, kde = True)
plt.title("Monthly Income Distribution")
plt.show()

# %%
df = df.rename(columns = {"Yes=1 and No=0":"Attrition"})

# %%
sns.boxplot(x='Attrition', y='StockOptionLevel', data=df)
plt.title('Stock Option Level vs. Attrition')
plt.show()

# %%
new_df = df[['MonthlyIncome',"Department"]].copy()
new_df
# Out:
#       MonthlyIncome              Department
# 0              5993                   Sales
# 1              5130  Research & Development
# 2              2090  Research & Development
# 3              2909  Research & Development
# 4              3468  Research & Development
# ...             ...                     ...
# 1465           2571  Research & Development
# 1466           9991  Research & Development
# 1467           6142  Research & Development
# 1468           5390                   Sales
# 1469           4404  Research & Development
#
# [1470 rows x 2 columns]

# %%
new_df.style.format().hide_index()\
                 .bar(subset=["MonthlyIncome",], color='green')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7256\1987429956.py:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   new_df.style.format().hide_index()\
# <style type="text/css">
# #T_93a60_row0_col0, #T_93a60_row59_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 30.0%, transparent 30.0%);
# }
# #T_93a60_row1_col0, #T_93a60_row1253_col0, #T_93a60_row1440_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 25.7%, transparent 25.7%);
# }
# #T_93a60_row2_col0, #T_93a60_row419_col0, #T_93a60_row441_col0, #T_93a60_row478_col0, #T_93a60_row864_col0, #T_93a60_row934_col0, #T_93a60_row1017_col0, #T_93a60_row1035_col0, #T_93a60_row1258_col0, #T_93a60_row1321_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, green 10.5%, transparent 10.5%);
# }
# #T_93a60_row3_col0, #T_93a60_row345_col0, #T_93a60_row642_col0, #T_93a60_row1056_col0, #T_93a60_row1397_col0 {
#   width: 10em;
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1470 non-null   object
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobLevel                  1470 non-null   int64
#  12  JobRole                   1470 non-null   object
#  13  JobSatisfaction           1470 non-null   int64
# ...
